# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('zomato.csv',encoding = 'latin-1')
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
#Basic EDA

# %% [markdown]
# ## In Data Analysis what we do
#
# 1. Missing Values
# 2. Explore About the Numerical Variables
# 3. Explore About the Categorical Variables
# 4. Finding Relationship between Feature

# %%
#df.column()
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Use pandas documentatio , Why encodin and UTF is used?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# # What we do in EDA

# %%
df.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
# 1. Find Missing Values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
features for features in df.columns if df[features].isnull().sum()>1

# lits a list comperhension
# Out:
#   File "<ipython-input-8-ac558cee21b1>", line 1
#     features for features in df.columns if df[features].isnull().sum()>1
#              ^
# SyntaxError: invalid syntax

# %%
df.shape
# Out:
# (9551, 21)

# %%
# For every features in Row and Column, go and check
    # if df of columns (df.columns[which is represnted by features]) is null and greater than 0

[features for features in df.columns if df[features].isnull().sum()>0]

# its a list comperhension
# Out:
# ['Cuisines']

# %%
# Create heatmap with condition -
#       is there any column with null?
#       We don't want to show much things on y, so yticklabels = F
#       cmap = 'viridis' -> good way to get diagram, cmaps.viridis is a matplotlib.colors.ListedColormap

sns.heatmap(df.isnull(),yticklabels=False,cbar = False, cmap = 'viridis')

# blues,BuPu, Accent can be used instead of 'viridis', it's just a color pattern

# %% [markdown]
# # Explore Country Dataset

# %%
df_country = pd.read_excel('Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
pip install xlrd

# %%
df_country = pd.read_excel('Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
pip install openpyxl

# %%
df_country = pd.read_excel('Country-Code.xlsx')
df_country.head()

# use pd.read_excel for excel
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Country_Code Dataset

# %% [markdown]
# ### Can we combine two dataframes?

# %%
# yes, we can

# %%
#use merge() from pandas
# Dataframe|Series -> df,df_country
# on which feature we gonna combine two Tables -> on= 'Country Code'
# how to join? Left , right or inner join

pd.merge(df,df_country, on= 'Country Code', how = 'left' )
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
final_df = pd.merge(df,df_country, on= 'Country Code', how = 'left' )

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
# TO check datatypes use dtypes

final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# How many countries are there?
# With respect to each country hoe many records are there in database?

final_df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# South Africa        60
# UAE                 60
# Brazil              60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Sri Lanka           20
# Qatar               20
# Singapore           20
# Canada               4
# Name: Country, dtype: int64

# %%
country_names = final_df.Country.value_counts().index

# we get countries

# %%
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'South Africa', 'UAE',
#        'Brazil', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Sri Lanka', 'Qatar', 'Singapore', 'Canada'],
#       dtype='object')

# %%
final_df.Country.value_counts().values
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %%
country_val = final_df.Country.value_counts().values

# we get number of records for each country name

# %%
country_val
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %% [markdown]
# ## Pie Charts

# %%
plt.pie(country_val, labels = country_names)

# plt.pie( x axis, labels to label on graphs )
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef3bf845e0>,
# ...
#  [Text(-1.052256163793291, 0.3205572737577906, 'India'),
#   Text(0.9911329812843455, -0.477132490415823, 'United States'),
#   Text(1.0572858296119743, -0.3035567072257165, 'United Kingdom'),
#   Text(1.070138816916019, -0.2545641619112621, 'South Africa'),
#   Text(1.0793506814479759, -0.21213699926648824, 'UAE'),
#   Text(1.086881147244973, -0.16937937230799818, 'Brazil'),
#   Text(1.0918635911832035, -0.1335436192729486, 'New Zealand'),
#   Text(1.0947903814016446, -0.10692998078388304, 'Turkey'),
#   Text(1.096631023945382, -0.08602556201794338, 'Australia'),
#   Text(1.0978070729776455, -0.06942355882735218, 'Phillipines'),
#   Text(1.0986791544015209, -0.05388984768543213, 'Indonesia'),
#   Text(1.0993059848742366, -0.039068550263413035, 'Sri Lanka'),
#   Text(1.0997248508282123, -0.02460187941736628, 'Qatar'),
#   Text(1.0999533462179636, -0.010130949802716446, 'Singapore'),
# ...

# %%
## Pie Chart - with Top 3 using zomato mostly

import matplotlib
matplotlib.rcParams['figure.figsize'] = (12, 6)
plt.pie(country_val[:3], labels = country_names[:3])
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef3d3977f0>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')])

# %%
# autopercentage

plt.pie(country_val[:3], labels = country_names[:3]) , autopct = '%1.2f%%')
# Out:
#   File "<ipython-input-29-a0efc6375af9>", line 3
#     plt.pie(country_val[:3], labels = country_names[:3]) , autopct = '%1.2f%%')
#                                                                               ^
# SyntaxError: unmatched ')'

# %%
plt.pie(country_val[:3], labels = country_names[:3] , autopct = '%1.2f%%')

# add percentage with TWO VALUES after decimal -> autopct = '%1.2f%%'
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef3d3dfb20>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %%
plt.pie(country_val[:3], labels = country_names[:3] , autopct = '%1.10f%%')

# add percentage with TEN VALUES after decimal -> autopct = '%1.10f%%'
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef3d40bbb0>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.3923175335%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.7348897904%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.8727907203%')])

# %% [markdown]
# ## Observation:
#
#         -Zomato maximum records or transaction are from India After that USA and then United Kingdoms

# %%
# Find more observations and relations

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# ## Relationships beweent features/records

# %%
# groupby -> allows you to split your data into separate groups to perform computations for better analysis

final_df.groupby(['Aggregate rating','Rating color', 'Rating text'])

# %%
# We just created DataFrameGroupBy object above

# %%
final_df.groupby(['Aggregate rating','Rating color', 'Rating text']).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %%
# convert into dataframe

final_df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index()
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2148
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    27
# 6                2.3          Red        Poor    47
# 7                2.4          Red        Poor    87
# 8                2.5       Orange     Average   110
# 9                2.6       Orange     Average   191
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   315
# 12               2.9       Orange     Average   381
# 13               3.0       Orange     Average   468
# 14               3.1       Orange     Average   519
# 15               3.2       Orange     Average   522
# 16               3.3       Orange     Average   483
# ...

# %%
# rename above 0 column_name with 'Rating Count'

final_df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
# Relationship we different countries

# %% [markdown]
# ## Observations:
#
#         1. When Rating is between 4.5 to 4.9---> Excellent
#         2. When Rating are between 4.0 to 3.4--->very good
#         3. when Rating is between 3.5 to 3.9----> good
#         4. when Rating is between 3.0 to 3.4----> average
#         5. when Rating is between 2.5 to 2.9----> average
#         6. when Rating is between 2.0 to 2.4----> Poor

# %%
ratings.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a5d1d4105667> in <module>
# ----> 1 ratings.head()
#
# NameError: name 'ratings' is not defined

# %%
ratings = final_df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
ratings.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', data = ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
#settings to improve size

# %%
matplotlib.rcParams['figure.figsize'] = (12,6)

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12,6)

# %%
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', data = ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', hue = 'Rating color', data = ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
# mapping the colors using pallette
# pallette -> allows to use our own colors as required

# %%
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', hue = 'Rating color', data = ratings, palette['white','red','orange','yellow','green','Dark green'])

# Dark Green -> Error reason
# Out:
#   File "<ipython-input-49-7640a15fe3fd>", line 1
#     sns.barplot(x = 'Aggregate rating', y = 'Rating Count', hue = 'Rating color', data = ratings, palette['white','red','orange','yellow','green','Dark green'])
#                                                                                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', hue = 'Rating color', data = ratings, palette = ['white','red','orange','yellow','green','green'])

# Dark green gives error
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', hue = 'Rating color', data = ratings, palette = ['blue','red','orange','yellow','green','green'])

# %% [markdown]
# Observations :-
#
#     1. Not Rated count is very high
#     2. Maximum number of rating are between 2.5 to 3.4

# %% [markdown]
# # count plot - based on categorical variable
#
# sns.countplot

# %%
sns.countplot(x= 'Rating Color', data = ratings, palette = ['blue','red','orange','yellow','green','green'])

# The below error is beacause of 'Rating' spelling mistake
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-033e480fcc7a> in <module>
# ----> 1 sns.countplot(x= 'Rating Color', data = ratings, palette = ['blue','red','orange','yellow','green','green'])
#       2
#       3 # The below error is beacause of 'Rating Color' spelling mistake
#
# ~\Anaconda3\envs\deeplearning\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\envs\deeplearning\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3593         raise ValueError("Cannot pass values for both `x` and `y`")
#    3594
# -> 3595     plotter = _CountPlotter(
# ...

# %%
sns.countplot( x = 'Rating color', data = ratings, palette = ['blue','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ## Let's find countries name that has given 0 ratings

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df[final_df['Rating color'] == 'White'] # not effective
# Out:
#       Restaurant ID         Restaurant Name  Country Code            City  \
# 30          6600060          Sandubas Cafí©            30       Brasí_lia
# 58          7305048   Quiosque Chopp Brahma            30  Rio de Janeiro
# 69          6710645        Cantinho da Gula            30      Sí£o Paulo
# 77          6701419           Divino Fogí£o            30      Sí£o Paulo
# 78          6703956             Super Grill            30      Sí£o Paulo
# ...             ...                     ...           ...             ...
# 9109       18277023           Bread & Pasta             1           Noida
# 9110       18313203           Chillies Cafe             1           Noida
# 9111       18254559                Platters             1           Noida
# 9112       18255132               The Grand             1           Noida
# 9351       18273002  Damascena Coffee House           215      Birmingham
#
#                                                 Address  \
# ...

# %%
final_df[final_df['Rating color'] == 'White'].groupby('Country').size().reset_index() # effective
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %%
final_df[final_df['Aggregate rating'] == 0 ].head(2) # not effective
# Out:
#     Restaurant ID        Restaurant Name  Country Code            City  \
# 30        6600060         Sandubas Cafí©            30       Brasí_lia
# 58        7305048  Quiosque Chopp Brahma            30  Rio de Janeiro
#
#                                               Address   Locality  \
# 30  Edifí_cio Josí© Severo, SCS 6, Bloco A, Loja 9...    Asa Sul
# 58  Madureira Shopping - Loja 289/290, Piso 2, Est...  Madureira
#
#              Locality Verbose  Longitude   Latitude             Cuisines  ...  \
# 30         Asa Sul, Brasí_lia -47.890167 -15.797000      Brazilian, Cafe  ...
# 58  Madureira, Rio de Janeiro -43.341164 -22.870413  Bar Food, Brazilian  ...
#
#     Has Table booking Has Online delivery Is delivering now  \
# 30                 No                  No                No
# 58                 No                  No                No
#
#    Switch to order menu Price range Aggregate rating  Rating color  \
# ...

# %%
final_df.groupby(['Aggregate rating', 'Country']).size().head(2) # not effective
# Out:
# Aggregate rating  Country
# 0.0               Brazil        5
#                   India      2139
# dtype: int64

# %%
final_df.groupby(['Aggregate rating', 'Country']).size().reset_index().head() # effective
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3
# 4               1.8           India     1

# %% [markdown]
# ### Let's find which country use which currency

# %%
df_country.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby(['Country','Currency']).size().head()
# Out:
# Country    Currency
# Australia  Dollar($)                   24
# Brazil     Brazilian Real(R$)          60
# Canada     Dollar($)                    4
# India      Indian Rupees(Rs.)        8652
# Indonesia  Indonesian Rupiah(IDR)      21
# dtype: int64

# %%
final_df.groupby(['Country','Currency']).size().reset_index().head()
# Out:
#      Country                Currency     0
# 0  Australia               Dollar($)    24
# 1     Brazil      Brazilian Real(R$)    60
# 2     Canada               Dollar($)     4
# 3      India      Indian Rupees(Rs.)  8652
# 4  Indonesia  Indonesian Rupiah(IDR)    21

# %%
final_df.groupby(['Country','Currency']).size().reset_index().head()
# Out:
#      Country                Currency     0
# 0  Australia               Dollar($)    24
# 1     Brazil      Brazilian Real(R$)    60
# 2     Canada               Dollar($)     4
# 3      India      Indian Rupees(Rs.)  8652
# 4  Indonesia  Indonesian Rupiah(IDR)    21

# %%
final_df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index().head()
# Out:
#      Country                Currency     0
# 0  Australia               Dollar($)    24
# 1     Brazil      Brazilian Real(R$)    60
# 2     Canada               Dollar($)     4
# 3      India      Indian Rupees(Rs.)  8652
# 4  Indonesia  Indonesian Rupiah(IDR)    21

# %% [markdown]
# ## Find countries have online delivery

# %%
final_df(['Country','Has Online delivery'])  # not effective
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-9ccd03ff058f> in <module>
# ----> 1 final_df(['Country','Has Online delivery'])
#
# TypeError: 'DataFrame' object is not callable

# %%
final_df.groupby(['Country','Has Online delivery')].size().reset_index().head(10) # not efficient
# Out:
#   File "<ipython-input-69-d2850c90e06d>", line 1
#     final_df.groupby(['Country','Has Online delivery')].size().reset_index().head(10) # not efficient
#                                                      ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby(['Country','Is delivering now']).size() # not efficient
# Out:
# Country         Is delivering now
# Australia       No                     24
# Brazil          No                     60
# Canada          No                      4
# India           No                   8618
#                 Yes                    34
# Indonesia       No                     21
# New Zealand     No                     40
# Phillipines     No                     22
# Qatar           No                     20
# Singapore       No                     20
# South Africa    No                     60
# Sri Lanka       No                     20
# Turkey          No                     34
# UAE             No                     60
# United Kingdom  No                     80
# United States   No                    434
# dtype: int64

# %%
final_df.groupby(['Country','Is delivering now']).size().reset_index() # not efficient
# Out:
#            Country Is delivering now     0
# 0        Australia                No    24
# 1           Brazil                No    60
# 2           Canada                No     4
# 3            India                No  8618
# 4            India               Yes    34
# 5        Indonesia                No    21
# 6      New Zealand                No    40
# 7      Phillipines                No    22
# 8            Qatar                No    20
# 9        Singapore                No    20
# 10    South Africa                No    60
# 11       Sri Lanka                No    20
# 12          Turkey                No    34
# 13             UAE                No    60
# 14  United Kingdom                No    80
# 15   United States                No   434

# %%
final_df[final_df['Has Online delivery']== 'Yes'].Country.value_counts().reset_index() # Exact Solution
# Out:
#    index  Country
# 0  India     2423
# 1    UAE       28

# %%
final_df[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %% [markdown]
# ## Observations:
#
#     -  Online Deliveries are available in India and UAE

# %% [markdown]
# ## Create pie-chart for cities distribution

# %%
final_df.City.value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad', 'Lucknow',
#        'Amritsar', 'Bhubaneshwar', 'Guwahati', 'Ahmedabad',
#        ...
#        'Paynesville', 'Beechworth', 'Forrest', 'Miller', 'Consort', 'Tanunda',
#        'Armidale', 'Lincoln', 'Randburg', 'Cochrane'],
#       dtype='object', length=141)

# %%
# plt.pie(final_df.City.value_counts().values,labels = final_df.City.value_counts().index) 

#above is bit complicate, let's make it simple

# %%
city_values = final_df.City.value_counts().values

#city_index = final_df.City.value_counts().index

city_labels = final_df.City.value_counts().index

# %%
plt.pie(city_values,city_labels) # Error: missed -> label = city_labels
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-f66cca761270> in <module>
# ----> 1 plt.pie(city_values,city_labels) # Error: missed -> label = city_labels
#
# ~\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
#    2829         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ~\Anaconda3\envs\deeplearning\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
plt.pie(city_values,labels = city_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef3f60aa30>,
# ...
#  [Text(-0.2501618674207579, 1.0711764747643402, 'New Delhi'),
#   Text(-0.745121915719338, -0.8091930120278745, 'Gurgaon'),
#   Text(-0.023335860702208486, -1.0997524437823665, 'Noida'),
#   Text(0.4451062250173843, -1.0059226851258372, 'Faridabad'),
#   Text(0.5344697170236794, -0.9614271275477035, 'Ghaziabad'),
#   Text(0.5489550432957175, -0.9532304865247423, 'Lucknow'),
#   Text(0.5620711022307091, -0.9455559613461045, 'Amritsar'),
#   Text(0.5750798895062447, -0.9377009761568373, 'Bhubaneshwar'),
#   Text(0.5879789223862543, -0.9296670300863097, 'Guwahati'),
#   Text(0.6007657390813725, -0.9214556564186973, 'Ahmedabad'),
#   Text(0.6131375319471077, -0.9132701500201403, 'Rest of Hawaii'),
#   Text(0.625100125752387, -0.9051242084843107, 'Kanpur'),
#   Text(0.6369545100691332, -0.8968215832051494, 'Columbus'),
#   Text(0.6486986328151094, -0.888363711428944, 'Ranchi'),
#   Text(0.6603304609951781, -0.8797520572763077, 'Indore'),
# ...

# %%
plt.pie(city_values[:5],labels = city_labels[:5])
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef3f47e040>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')])

# %%
plt.pie(city_values[:5],labels = city_labels[:5],autopct='1.5%%')

# Error : autopct='1.5%%'
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef3f2edd30>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '1.5%'),
#   Text(0.0340186500653484, -0.5990348332507311, '1.5%'),
#   Text(0.47940246685229276, -0.36079533641101336, '1.5%'),
#   Text(0.5957573682667329, -0.07122610585941394, '1.5%'),
#   Text(0.5999706981848791, -0.005929698099289049, '1.5%')])

# %%
plt.pie(city_values[:5],labels = city_labels[:5],autopct='%1.5f%%')

# Solution
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef3f648e20>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.86876%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.06820%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59003%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.15842%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31458%')])

# %% [markdown]
# Observation :-
#     1. Maximum Transaction happens in New Delhi

# %%
## Assignment : Find Top 5 cuisines
